# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('country_wise_latest.csv')
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
plt.plot(df['Deaths'],df['Recovered'])

# %%
df.plot(kind='scatter',x='Deaths',y='Recovered')
plt.grid()
plt.plot()
# Out:
# []

# %%
df['Country/Region'].value_counts()
# Out:
# Afghanistan    1
# Pakistan       1
# Nepal          1
# Netherlands    1
# New Zealand    1
#               ..
# Georgia        1
# Germany        1
# Ghana          1
# Greece         1
# Zimbabwe       1
# Name: Country/Region, Length: 187, dtype: int64

# %%
sns.set(style="darkgrid")
sns.scatterplot(x='Deaths',y='Recovered', hue='WHO Region',data=df)
# Out:
# <AxesSubplot:xlabel='Deaths', ylabel='Recovered'>

# %%
bar_width=35
plt.bar(df['Country/Region'],df['Deaths'],bar_width,label='Dataset1')
plt.bar(df['Country/Region'],df['Recovered'],bar_width-20,label='Dataset2')
plt.xlabel('Country/Region')
plt.ylabel('Deaths')
plt.legend()
plt.show()

# %%
sns.relplot(x='Deaths',y='Recovered',hue='WHO Region',data=df)

# %%
sns.catplot(x='Deaths',y='Recovered',hue='WHO Region',kind='bar',data=df)

# %%
sns.catplot(x='Deaths',y='Recovered',hue='WHO Region',kind='violin',data=df)

# %%
sns.catplot(x='Deaths',y='Recovered',hue='WHO Region',kind='box',data=df)

# %%
print(sns.get_dataset_names())
# sns.set(style='darkgrid')
# Iris=sns.load_dataset('iris.csv')
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x='sepal_length',y='petal_length',data=iris)

# %%
sns.catplot(x='sepal_length',y='petal_length',kind='box',hue='species',data=iris)

# %%
sns.catplot(x='sepal_length',y='petal_length',kind='violin',hue='species',data=iris)

# %%
sns.catplot(x='sepal_length',y='petal_length',kind='bar',hue='species',data=iris)

# %%
ax=sns.catplot(x='sepal_length',kind='count',hue='species',data=iris)
ax.fig.autofmt_xdate()

# %%
sns.FacetGrid(iris,hue='species',height=6).map(plt.scatter,'sepal_length','petal_length').add_legend()

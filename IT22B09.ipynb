# %%
import pandas as pd
import numpy as np

# %%
flt=pd.read_csv("flight.csv")
flt
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
flt.tail()
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 194            1917      -12.0      B6    1016  N304JB    JFK  BOS      36.0
# 195            2110       -5.0      B6     989  N663JB    JFK  FLL     152.0
# 196            1943       37.0      UA    1676  N37274    EWR  ORD     135.0
# 197            1949        8.0      EV    4581  N13566    EWR  CMH      95.0
# 198            1951       -6.0      B6    1111  N294JB    JFK  RDU      78.0
#
#      distance  hour  minute         time_hour
# ...

# %%
flt['flight'].sum()
# Out:
# 359333

# %%
flt['speed']=flt['distance']/flt['hour']*flt['minute']*60
flt
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
flt.size
# Out:
# 3980

# %%
flt.shape
# Out:
# (199, 20)

# %%
flt.drop_duplicates()
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
flt.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'speed'],
#       dtype='object')

# %%
flt.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         3
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          3
# distance          0
# hour              0
# minute            0
# time_hour         0
# speed             0
# dtype: int64

# %%
ard=flt['arr_delay']
art=flt['air_time']
print(ard)
print(art)
# Out:
# 0      10.0
# 1     -17.0
# 2      17.0
# 3      17.0
# 4     -17.0
#        ...
# 194   -12.0
# 195    -5.0
# 196    37.0
# 197     8.0
# 198    -6.0
# Name: arr_delay, Length: 199, dtype: float64
# 0       87.0
# 1      152.0
# 2      140.0
# 3      252.0
# 4      166.0
#        ...
# 194     36.0
# 195    152.0
# 196    135.0
# 197     95.0
# 198     78.0
# Name: air_time, Length: 199, dtype: float64

# %%
ard_mean=ard.mean()
art_mean=art.mean()
print(ard_mean)
print(art_mean)
# Out:
# 15.183673469387756
# 168.98979591836735

# %%
flt.fillna(ard_mean,inplace=True)
flt.fillna(art_mean,inplace=True)
flt
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
flt.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         0
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          0
# distance          0
# hour              0
# minute            0
# time_hour         0
# speed             0
# dtype: int64

# %%
f_min=flt['dep_delay'].min()
f_min
# Out:
# -14

# %%
flt[(flt['flight']==f_min)]
# Out:
# Empty DataFrame
# Columns: [year, month, day, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, carrier, flight, tailnum, origin, dest, air_time, distance, hour, minute, time_hour, speed]
# Index: []

# %%
cdf=pd.read_csv('cars.csv')
cdf
# Out:
#      Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0             0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1             1   2899       ford       se  2011  clean vehicle  190552.0
# 2             2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3             3  25000       ford     door  2014  clean vehicle   64146.0
# 4             4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ..          ...    ...        ...      ...   ...            ...       ...
# 172         172   5470      dodge      mpv  2018  clean vehicle   39721.0
# 173         173  14600       ford     door  2014  clean vehicle   75785.0
# 174         174  24502  chevrolet     1500  2016  clean vehicle   33624.0
# 175         175  15110       ford     door  2017  clean vehicle   42289.0
# 176         176   7900       ford     door  2014  clean vehicle   79422.0
#
#       color                  vin        lot         state country  \
# ...

# %%
cdf.size
# Out:
# 2301

# %%
cdf.shape
# Out:
# (177, 13)

# %%
cdf[(cdf['color']=='black')].count()
# Out:
# Unnamed: 0      43
# price           43
# brand           43
# model           43
# year            43
# title_status    43
# mileage         43
# color           43
# vin             43
# lot             43
# state           43
# country         43
# condition       43
# dtype: int64

# %%
cdf['brand'].max()
# Out:
# 'toyota'

# %%
cdf.describe()
# Out:
#        Unnamed: 0         price         year        mileage           lot
# count  177.000000    177.000000   177.000000     174.000000  1.770000e+02
# mean    88.000000  17121.751412  2016.310734   47320.896552  1.676768e+08
# std     51.239633  11060.554802     4.084275   37487.489398  6.342515e+05
# min      0.000000      0.000000  1973.000000    2430.000000  1.593488e+08
# 25%     44.000000   7300.000000  2016.000000   29187.250000  1.676565e+08
# 50%     88.000000  15110.000000  2017.000000   36013.500000  1.677554e+08
# 75%    132.000000  23505.000000  2018.000000   48796.250000  1.677637e+08
# max    176.000000  55000.000000  2020.000000  274117.000000  1.678025e+08

# %%
cdf.drop_duplicates()
# Out:
#      Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0             0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1             1   2899       ford       se  2011  clean vehicle  190552.0
# 2             2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3             3  25000       ford     door  2014  clean vehicle   64146.0
# 4             4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ..          ...    ...        ...      ...   ...            ...       ...
# 172         172   5470      dodge      mpv  2018  clean vehicle   39721.0
# 173         173  14600       ford     door  2014  clean vehicle   75785.0
# 174         174  24502  chevrolet     1500  2016  clean vehicle   33624.0
# 175         175  15110       ford     door  2017  clean vehicle   42289.0
# 176         176   7900       ford     door  2014  clean vehicle   79422.0
#
#       color                  vin        lot         state country  \
# ...

# %%
cdf.isnull().sum()
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         3
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
cdf.head(6)
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# 5           5   5700      dodge      mpv  2018  clean vehicle   45561.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# ...

# %%
mleg=cdf['mileage']
mleg
# Out:
# 0      274117.0
# 1      190552.0
# 2       39590.0
# 3       64146.0
# 4        6654.0
#          ...
# 172     39721.0
# 173     75785.0
# 174     33624.0
# 175     42289.0
# 176     79422.0
# Name: mileage, Length: 177, dtype: float64

# %%
mleg_median=mleg.median()
mleg_median
# Out:
# 36013.5

# %%
cdf.fillna(mleg_median,inplace=True)

# %%
cdf.isnull().sum()
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
Idf=pd.read_csv('iris.csv')
Idf
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
Idf.head(4)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa

# %%
Idf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
Idf[(Idf['variety']=='Setosa')].count()
# Out:
# sepal.length    50
# sepal.width     50
# petal.length    50
# petal.width     50
# variety         50
# dtype: int64

# %%
Idf[(Idf['variety']=='Virginica')].count()
# Out:
# sepal.length    50
# sepal.width     50
# petal.length    50
# petal.width     50
# variety         50
# dtype: int64

# %%
Idf[(Idf['variety']=='Versicolor')].count()
# Out:
# sepal.length    50
# sepal.width     50
# petal.length    50
# petal.width     50
# variety         50
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Idf['sepal.length'],Idf['sepal.width'])

# %%
Idf.shape
# Out:
# (150, 5)

# %%
Idf.size
# Out:
# 750

# %%
Idf.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
Idf.iloc[80:101]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 80            5.5          2.4           3.8          1.1  Versicolor
# 81            5.5          2.4           3.7          1.0  Versicolor
# 82            5.8          2.7           3.9          1.2  Versicolor
# 83            6.0          2.7           5.1          1.6  Versicolor
# 84            5.4          3.0           4.5          1.5  Versicolor
# 85            6.0          3.4           4.5          1.6  Versicolor
# 86            6.7          3.1           4.7          1.5  Versicolor
# 87            6.3          2.3           4.4          1.3  Versicolor
# 88            5.6          3.0           4.1          1.3  Versicolor
# 89            5.5          2.5           4.0          1.3  Versicolor
# 90            5.5          2.6           4.4          1.2  Versicolor
# 91            6.1          3.0           4.6          1.4  Versicolor
# ...

# %%
Idf.drop_duplicates()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [149 rows x 5 columns]

# %%
Idf.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
mdf=pd.read_csv('Movie-Data.csv')
mdf
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
plt.plot(mdf['Runtime (Minutes)'])

# %%
mdf.size
# Out:
# 12000

# %%
mdf.shape
# Out:
# (1000, 12)

# %%
mdf.drop_duplicates()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
mdf.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
max=mdf['Revenue (Millions)'].max()
print(max)
min=mdf['Revenue (Millions)'].min()
print(min)
# Out:
# 936.63
# 0.0

# %%
mdf[(mdf['Revenue (Millions)']==max)]
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 50                136     8.1  661608              936.63       81.0

# %%
mdf[(mdf['Revenue (Millions)']==min)]
# Out:
#      Rank             Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 231                 95     5.2   3305                 0.0       50.0

# %%
mdf[(mdf['Revenue (Millions)']== 0)]
# Out:
#      Rank             Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 231                 95     5.2   3305                 0.0       50.0

# %%
ddf=pd.read_csv('diamonds.csv')
ddf
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
min=ddf['price'].min()
print(min)
max=ddf['price'].max()
print(max)
# Out:
# 326
# 2777

# %%
plt.plot(max,min)

# %%
plt.plot(ddf['price'],ddf['carat'])

# %%
ddf[((ddf['x']== 0)|(ddf['y']== 0)|(ddf['z']== 0))]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
ddf.describe()
# Out:
#             carat       depth       table        price           x  \
# count  199.000000  199.000000  199.000000   199.000000  199.000000
# mean     0.524020   61.629146   57.719598  1712.035176    5.047588
# std      0.237057    1.613471    2.355365  1166.046417    0.834121
# min      0.200000   55.100000   53.000000   326.000000    3.790000
# 25%      0.290000   60.800000   56.000000   404.000000    4.225000
# 50%      0.700000   61.700000   57.000000  2760.000000    5.560000
# 75%      0.720000   62.600000   59.000000  2768.000000    5.790000
# max      1.170000   66.300000   69.000000  2777.000000    6.830000
#
#                 y           z
# count  199.000000  199.000000
# mean     5.055075    3.112462
# std      0.823563    0.512692
# min      3.750000    2.270000
# 25%      4.250000    2.615000
# 50%      5.580000    3.380000
# 75%      5.780000    3.560000
# max      6.900000    4.130000

# %%
ddf.drop_duplicates()
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
ddf.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
ddf['total']=ddf['x']*ddf['y']*ddf['z']
ddf
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z  \
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
#           total
# 0     38.202030
# 1     34.505856
# 2     38.076885
# 3     46.724580
# ...
